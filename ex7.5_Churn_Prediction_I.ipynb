# %% [markdown]
# # Intro to Classification 02
#
#
# ## Churn Prediction!
#
# ### Your name:
#
# #### 실습목표<br>
# 장바구니 데이터 부터, 이탈 예측 까지.
# ---------------
# Rayleigh Kim

# %%
'''
라이브러리들을 불러오자.
'''
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## 고민해야할 포인트 부터!

# %% [markdown]
# **상황설정**
#
# 1. 일단 아래의 데이터를 관찰해보자.
# 2. 마케팅 담당자는 당신에게 요구했다. '이탈자'를 예측해달라.
# 3. E-commerce가 아니다.
# 4. 회원제로 운영되는 동네 슈퍼마켓(!)이라고 생각하면 좋다.

# %% [markdown]
# ### Q1. 우리가 관찰한 데이터로 부터 바로 이탈예측을 할 수 있는가?  무엇이 필요한가?

# %% [markdown]
# ### Q2. '이탈자'를 정의해보자.
#
# 정말 중요한 작업이다. 여러분의 아이디어를 적어보자.
#
# 예상되는 마케팅 담당자의 반응(?)과 의사소통 과정 등을  시나리오처럼 적어보아도 **정말**좋다.

# %% [markdown]
# ### Q3. 문제 정의를 다시, 깔끔하게 해보자.
#
# 0. 문제를 '구체적으로' 정의하라
# 1. 데이터가 이러한 형태면 적절한가? 무엇을 더 해야 할까?
# 2. 문제 정의에 따라서, 데이터에서 제거해야할 부분들이 있다. 무엇일까?

# %% [markdown]
# ### Q4. 모델링에 대하여
#
# 1. 어떤 모델을 쓸 것인가. 그 이유는?
# 2. 모델을 여러개 만들고 선택해야할 수도 있다. 주로 어떤 상황에 그러하게 될까?

# %% [markdown]
# ### Q5. (Very Advanced)평가에 대하여.
#
# 1. Cross_Entropy, Confusion Matrix 복습은 한 번쯤 해보자.
# 2. 1번은, 중요한 기본이다. 실전에서는 더 나가야 한다. **돈으로 이야기하려면, 어떻게 해야 할까.**

# %% [markdown]
# ### 먼 훗날. (Very Advanced) 실제 시스템에 올린다면.
#
# 1. 데이터가 시계열인지 아닌지, 문제를 시계열로 풀어야 하는지 아닌지에 따라서 처음 모델링 과정이 바뀐다.
#
# 2. 실제 시스템에 올린다면, 문제를 푸는 구조가 어떻게 되어야 할지 말끔하게 정리해보자.

# %% [markdown]
# ## Data Loading & Preparation
#
# 이번 실습은 다음의 정말 중요한 과정을 완료하는 것이 목표이다.
#
# Raw_data 에서, **어떤 과정**을 거치면 굉장히 잘 정돈된 Data를 얻게 된다.
#
# **어떤 과정이란 다음과 같다.**
# 1. 원래 데이터는 어떻게 생겼는가?
# 2. 문제 정의
#     * 이탈자는 어떻게 정의할 것인가.
#     * 어떤 기간의 데이터로, 어떤 기간을 예측할 것인가.
# 3. Data Wrangling & Feature Engineering
#
#
# 다음의 데이터들을 구경해보자. 로컬에서 csv파일을 엑셀로 열어도 좋다.

# %%
'''
고객 정보 데이터
'''
user_info = pd.read_csv('https://raw.githubusercontent.com/RayleighKim/Example_datasets/master/RetailChurn_UserInfoData.csv')
user_info.head()

# %%
'''
Transaction 데이터
'''

raw_data = pd.read_csv('https://raw.githubusercontent.com/RayleighKim/Example_datasets/master/transaction_sample.csv')
raw_data.head()

# %% [markdown]
# ## 너무 힘들 때, 미리 보기
#
# 하지만 우리는 아래와 같은 데이터여야 머신러닝을 할 수 있다
#
# 첨부된 데이터 파일 **(new주석, 공개)RetailChurnTemplate_FeatureEngg.xlsx**를 먼저 구경하고 와도 좋다

# %%
churn = pd.read_csv('https://raw.githubusercontent.com/RayleighKim/Example_datasets/master/RetailChurnTemplate_FeatureEngg.csv')
'''
아래의 코드는 row를 셔플하기 위해 필요하다.
'''
churn = churn.sample(frac = 1, random_state = 2018).reset_index(drop=True)

churn.head()
